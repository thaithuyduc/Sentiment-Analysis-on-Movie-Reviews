# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from collections import OrderedDict
from typing import Literal, Optional
from sklearn.metrics import f1_score
import copy
from matplotlib.ticker import FuncFormatter
from matplotlib.axes import Axes
from matplotlib.figure import Figure
import seaborn.objects as so
import math
import itertools
import matplotlib.ticker as mticker
import random

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
dfFilm_C = pd.read_csv("Dataset/film_cleaned_ver2.csv") #file sau khi gán thủ công
dfFilm_C.head()
# Out:
#                    author                                            comment  \
# 0       Nguyễn Thanh Trúc  Ta nói nó hài . Bản thân t con gái nhưng rất t...
# 1           Trần Công Lập  Hên là coi ở CGV, phim gì mà nhân vật nói chả ...
# 2  Nguyễn Bảo Thoại Trinh  phim hài, cười banh rạp =)))) Nửa tiếng đầu mì...
# 3         Dương Thanh Huy  Nếu bỏ tiền mua vé xem Phim Việt thì tui tốn c...
# 4     Trần Thị Thanh Sang  Phim hay và ý nghĩa. Cười rất nhiều. Có nhìu h...
#
#   ratings                     title  \
# 0    5/10  Truy Tìm Long Diên Hương
# 1    2/10  Truy Tìm Long Diên Hương
# 2    7/10  Truy Tìm Long Diên Hương
# 3    5/10  Truy Tìm Long Diên Hương
# 4    5/10  Truy Tìm Long Diên Hương
#
#                                                  url  \
# 0  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 1  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 2  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 3  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 4  https://www.momo.vn/cinema/truy-tim-long-dien-...
#
#                                         cleaned_text  length  has_emoji  \
# 0  ta nói nó hài bản thân tôi con gái nhưng rất t...      23          0
# 1  hên coi ở cgv phim gì nhân vật nói chả nghe cá...      51          0
# 2  phim hài cười banh rạp = nửa tiếng đầu mình bi...      36          0
# 3  nếu bỏ tiền mua vé xem phim việt tui tốn chưa ...     231          0
# 4  phim hay ý nghĩa cười rất nhiều có nhìu hành đ...      14          0
#
#       label
# 0  positive
# 1  negative
# 2  positive
# 3  positive
# 4  positive

# %%
# Lấy ra những cột thật sự cần cho SA
df_needed = dfFilm_C[['cleaned_text', 'label']]
df_needed.head()
# Out:
#                                         cleaned_text     label
# 0  ta nói nó hài bản thân tôi con gái nhưng rất t...  positive
# 1  hên coi ở cgv phim gì nhân vật nói chả nghe cá...  negative
# 2  phim hài cười banh rạp = nửa tiếng đầu mình bi...  positive
# 3  nếu bỏ tiền mua vé xem phim việt tui tốn chưa ...  positive
# 4  phim hay ý nghĩa cười rất nhiều có nhìu hành đ...  positive

# %%
df_needed['label'].value_counts()
# Out:
# label
# positive         2005
# negative         1841
# mixed/neutral    1233
# none              328
# Name: count, dtype: int64

# %%
# Loại bỏ đi Label là none có trong dữ liệu
df_needed = df_needed[df_needed['label'].isin(['positive', 'negative', 'mixed/neutral'])]

# %% [markdown]
# # Prepare Data

# %%
# Xây dựng Vocabulary cho tập dữ liệu trên
def build_vocab(corpus: pd.Series) -> dict[str, int]:
    """
    Build vocabulary
    """
    # vectorize to get the vocabulary
    vocab_vectorizer = CountVectorizer(min_df=1, max_df=1.0, stop_words=None)
    matrix = vocab_vectorizer.fit_transform(corpus)
    vocab = vocab_vectorizer.vocabulary_
    
    df = pd.DataFrame(list(vocab.items()), columns=['word', 'index'])
    df['index'] = df['index'] + 2

    df_pad = pd.DataFrame(list({"<PAD>": 0, "<UNK>": 1}.items()), columns=["word", "index"])
    df = pd.concat([df, df_pad], axis=0, ignore_index=True)
    
    vocab = dict(zip(df['word'], df['index']))
    
    return vocab

# %%
# Tạo dictionary để map label thành số
label = df_needed['label'].unique()
idx = range(len(label))
label_mapping = dict(zip(label, idx))
label_mapping
# Out:
# {'positive': 0, 'negative': 1, 'mixed/neutral': 2}

# %%
# Chia tập dữ liệu thành train, val, test dataset
X = df_needed['cleaned_text']
y = df_needed['label']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.2, stratify=y_train, random_state=42)

# %%
vocab=build_vocab(X_train)
len(vocab)
# Out:
# 4913

# %%
from torch.nn.utils.rnn import pad_sequence
class SentimentDataset(Dataset):
    def __init__(self, vocab, text: pd.Series, label: pd.Series, label_mapping):
        super().__init__()
        self.vocab = vocab
        self.text = text
        self.label = label
        self.label_mapping = label_mapping

    def __len__(self):
        return len(self.text)

    def __getitem__(self, idx) -> tuple[torch.LongTensor, torch.LongTensor]:  # iterate through each sample, must have "idx"
        # get text at index
        text_item = self.text.iloc[idx]
        label_item = self.label.iloc[idx]

        # tokenize
        tokens = text_item.split()
        tokens_idx = [self.vocab[token] if token in self.vocab else self.vocab['<UNK>'] for token in tokens] # list
        label_idx = self.label_mapping[label_item]

        return torch.tensor(tokens_idx, dtype=torch.long), torch.tensor(label_idx, dtype=torch.long)

def collate_fn(batch) -> tuple[torch.LongTensor, torch.LongTensor]:
    tokens_idx, label = zip(*batch) # return tuples
    labels = torch.stack(label, dim=0)
    
    # Pad the sequences
    padded_sequences = pad_sequence(tokens_idx, batch_first=True,
                                    padding_value=vocab["<PAD>"])
    
    return padded_sequences, labels

# %%
train_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_train, label=y_train)

val_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_val, label=y_val)

test_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_test, label=y_test)

# %%
train_loader = DataLoader(train_dataset, batch_size = 512, shuffle=True, collate_fn = collate_fn)

val_loader = DataLoader(val_dataset, batch_size = 512, shuffle=False, collate_fn = collate_fn)

test_loader = DataLoader(test_dataset, batch_size = 512, shuffle=False, collate_fn = collate_fn)

# used to create mini-batch

# %% [markdown]
# # Build and Evaluate LSTM Models

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
epochs = 50

loss_function = nn.CrossEntropyLoss()
metric_fn = f1_score

lstm_params = {'vocab': vocab,
              'emb_dim': 128, 
              'num_classes': y_train.nunique(),
              'hidden_size': 128,
              'num_layers': 2,
              'bidirectional': True,
              'proj_size': 0,
              'pooling_fn': 'attention'
             }

# %%
from helper_class import ModelTraining
from Model.lstm import LSTMModel

model = LSTMModel(**lstm_params)
model = torch.nn.DataParallel(model)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr= 0.001, weight_decay=1e-3) # weight_decay=1e-3

performance = ModelTraining(model=model, optimizer=optimizer, loss_function=loss_function,
                             device=device, train_loader=train_loader, val_loader=val_loader,
                             test_loader=test_loader)

# %%
train_loss_collection, val_loss_collection, train_score_collection, val_score_collection, best_state = \
performance.training_session(epochs=epochs, metric_fn=metric_fn, kwargs={'average': 'macro'})
# Out:
# New best score in epoch 1: 0.421549876040283. Saving model parameters...
# =====================
# Epoch 1 completed
# Train Loss: 1.1022 ; Score: 0.35375020191073253
# Val Loss: 0.9626 ; Score: 0.421549876040283
# =====================
# New best score in epoch 2: 0.5959598828555249. Saving model parameters...
# =====================
# Epoch 2 completed
# Train Loss: 1.0149 ; Score: 0.429978290157987
# Val Loss: 0.8111 ; Score: 0.5959598828555249
# =====================
# New best score in epoch 3: 0.6693261344421205. Saving model parameters...
# =====================
# Epoch 3 completed
# Train Loss: 0.8848 ; Score: 0.5788520955254262
# Val Loss: 0.7471 ; Score: 0.6693261344421205
# =====================
# New best score in epoch 4: 0.6959570285620887. Saving model parameters...
# =====================
# Epoch 4 completed
# Train Loss: 0.7808 ; Score: 0.6593201976779275
# Val Loss: 0.6980 ; Score: 0.6959570285620887
# =====================
# New best score in epoch 5: 0.7192994821877837. Saving model parameters...
# =====================
# Epoch 5 completed
# Train Loss: 0.7448 ; Score: 0.6753273890230677
# Val Loss: 0.6742 ; Score: 0.7192994821877837
# =====================
# New best score in epoch 6: 0.7258398595894678. Saving model parameters...
# =====================
# Epoch 6 completed
# Train Loss: 0.7005 ; Score: 0.7007796759567232
# Val Loss: 0.6531 ; Score: 0.7258398595894678
# =====================
# New best score in epoch 7: 0.7361485062626896. Saving model parameters...
# =====================
# Epoch 7 completed
# Train Loss: 0.6686 ; Score: 0.7154828638271522
# Val Loss: 0.6306 ; Score: 0.7361485062626896
# =====================
# =====================
# Epoch 8 completed
# Train Loss: 0.6541 ; Score: 0.7203801747964929
# Val Loss: 0.6187 ; Score: 0.7357938178965183
# =====================
# New best score in epoch 9: 0.7511321002230092. Saving model parameters...
# =====================
# Epoch 9 completed
# Train Loss: 0.6025 ; Score: 0.7569622156574974
# Val Loss: 0.6200 ; Score: 0.7511321002230092
# =====================
# =====================
# Epoch 10 completed
# Train Loss: 0.5974 ; Score: 0.7614477759708205
# Val Loss: 0.6297 ; Score: 0.7467508622142048
# =====================
# =====================
# Epoch 11 completed
# Train Loss: 0.5840 ; Score: 0.7635708572575371
# Val Loss: 0.5837 ; Score: 0.7494452378751572
# =====================
# New best score in epoch 12: 0.7659783189403283. Saving model parameters...
# =====================
# Epoch 12 completed
# Train Loss: 0.5507 ; Score: 0.7756584457495227
# Val Loss: 0.5681 ; Score: 0.7659783189403283
# =====================
# =====================
# Epoch 13 completed
# Train Loss: 0.5267 ; Score: 0.7935428031971821
# Val Loss: 0.5856 ; Score: 0.7576408950185858
# =====================
# =====================
# Epoch 14 completed
# Train Loss: 0.5238 ; Score: 0.7928287464651751
# Val Loss: 0.5897 ; Score: 0.7577303118928388
# =====================
# New best score in epoch 15: 0.7810987409459497. Saving model parameters...
# =====================
# Epoch 15 completed
# Train Loss: 0.4859 ; Score: 0.8086263177991734
# Val Loss: 0.5585 ; Score: 0.7810987409459497
# =====================
# =====================
# Epoch 16 completed
# Train Loss: 0.4556 ; Score: 0.8228202827345706
# Val Loss: 0.5557 ; Score: 0.7743254462432545
# =====================
# =====================
# Epoch 17 completed
# Train Loss: 0.4207 ; Score: 0.8291811715722291
# Val Loss: 0.5670 ; Score: 0.7675821375195196
# =====================
# =====================
# Epoch 18 completed
# Train Loss: 0.4282 ; Score: 0.8277943195277305
# Val Loss: 0.5677 ; Score: 0.7691829431542635
# =====================
# New best score in epoch 19: 0.7849467961293514. Saving model parameters...
# =====================
# Epoch 19 completed
# Train Loss: 0.3979 ; Score: 0.8498516768751753
# Val Loss: 0.5458 ; Score: 0.7849467961293514
# =====================
# =====================
# Epoch 20 completed
# Train Loss: 0.4110 ; Score: 0.8387152644938894
# Val Loss: 0.5469 ; Score: 0.7797847145502077
# =====================
# =====================
# Epoch 21 completed
# Train Loss: 0.3683 ; Score: 0.8626461022939723
# Val Loss: 0.5720 ; Score: 0.7746757047794842
# =====================
# =====================
# Epoch 22 completed
# Train Loss: 0.3499 ; Score: 0.86753388877775
# Val Loss: 0.5876 ; Score: 0.7778929787223453
# =====================
# =====================
# Epoch 23 completed
# Train Loss: 0.3485 ; Score: 0.8677021457020461
# Val Loss: 0.5767 ; Score: 0.7815005246557624
# =====================
# =====================
# Epoch 24 completed
# Train Loss: 0.3559 ; Score: 0.8612861774815855
# Val Loss: 0.5854 ; Score: 0.7831993979434455
# =====================
# =====================
# Epoch 25 completed
# Train Loss: 0.3720 ; Score: 0.8524159684379634
# Val Loss: 0.5831 ; Score: 0.767992996124538
# =====================
# =====================
# Epoch 26 completed
# Train Loss: 0.3500 ; Score: 0.8591360498846935
# Val Loss: 0.5801 ; Score: 0.7703413037159423
# =====================
# =====================
# Epoch 27 completed
# Train Loss: 0.3357 ; Score: 0.8684725578967257
# Val Loss: 0.6145 ; Score: 0.7673122723451703
# =====================
# =====================
# Epoch 28 completed
# Train Loss: 0.3289 ; Score: 0.8729377993745016
# Val Loss: 0.6261 ; Score: 0.776190129603206
# =====================
# New best score in epoch 29: 0.7874094653837718. Saving model parameters...
# =====================
# Epoch 29 completed
# Train Loss: 0.2984 ; Score: 0.8903325282177187
# Val Loss: 0.6073 ; Score: 0.7874094653837718
# =====================
# =====================
# Epoch 30 completed
# Train Loss: 0.2973 ; Score: 0.8899165365328555
# Val Loss: 0.6186 ; Score: 0.7797381633618978
# =====================
# =====================
# Epoch 31 completed
# Train Loss: 0.3506 ; Score: 0.8604659517301508
# Val Loss: 0.5745 ; Score: 0.7823883645823901
# =====================
# =====================
# Epoch 32 completed
# Train Loss: 0.3181 ; Score: 0.8791957558852225
# Val Loss: 0.5999 ; Score: 0.7848680749656164
# =====================
# =====================
# Epoch 33 completed
# Train Loss: 0.2889 ; Score: 0.8916045578486997
# Val Loss: 0.6427 ; Score: 0.7714530585466949
# =====================
# =====================
# Epoch 34 completed
# Train Loss: 0.3357 ; Score: 0.8783402466495995
# Val Loss: 0.6318 ; Score: 0.7686882004300618
# =====================
# =====================
# Epoch 35 completed
# Train Loss: 0.3092 ; Score: 0.8771791810923198
# Val Loss: 0.5899 ; Score: 0.7815629139992742
# =====================
# =====================
# Epoch 36 completed
# Train Loss: 0.3016 ; Score: 0.8829953564163239
# Val Loss: 0.6519 ; Score: 0.760767223809684
# =====================
# New best score in epoch 37: 0.7887338028415498. Saving model parameters...
# =====================
# Epoch 37 completed
# Train Loss: 0.2984 ; Score: 0.8753993403985635
# Val Loss: 0.5868 ; Score: 0.7887338028415498
# =====================
# =====================
# Epoch 38 completed
# Train Loss: 0.2784 ; Score: 0.8905234769763561
# Val Loss: 0.5841 ; Score: 0.782459387783972
# =====================
# =====================
# Epoch 39 completed
# Train Loss: 0.2647 ; Score: 0.8992364049203493
# Val Loss: 0.6292 ; Score: 0.7768001258213753
# =====================
# New best score in epoch 40: 0.7905900785696182. Saving model parameters...
# =====================
# Epoch 40 completed
# Train Loss: 0.2533 ; Score: 0.899404859544204
# Val Loss: 0.6031 ; Score: 0.7905900785696182
# =====================
# =====================
# Epoch 41 completed
# Train Loss: 0.2367 ; Score: 0.9142187361139582
# Val Loss: 0.6386 ; Score: 0.7870320812604376
# =====================
# =====================
# Epoch 42 completed
# Train Loss: 0.2483 ; Score: 0.9039398631292003
# Val Loss: 0.6408 ; Score: 0.7777522267073569
# =====================
# =====================
# Epoch 43 completed
# Train Loss: 0.2310 ; Score: 0.908754756024395
# Val Loss: 0.6535 ; Score: 0.782302480719497
# =====================
# =====================
# Epoch 44 completed
# Train Loss: 0.2167 ; Score: 0.9200432179841114
# Val Loss: 0.6842 ; Score: 0.7860324006759534
# =====================
# =====================
# Epoch 45 completed
# Train Loss: 0.2270 ; Score: 0.9180956230709404
# Val Loss: 0.6432 ; Score: 0.789095986143799
# =====================
# New best score in epoch 46: 0.799394808615932. Saving model parameters...
# =====================
# Epoch 46 completed
# Train Loss: 0.2230 ; Score: 0.9178216367522444
# Val Loss: 0.6186 ; Score: 0.799394808615932
# =====================
# =====================
# Epoch 47 completed
# Train Loss: 0.2428 ; Score: 0.9093030166068431
# Val Loss: 0.6201 ; Score: 0.7742168879809329
# =====================
# =====================
# Epoch 48 completed
# Train Loss: 0.2305 ; Score: 0.9149889988930595
# Val Loss: 0.6360 ; Score: 0.777242644678034
# =====================
# =====================
# Epoch 49 completed
# Train Loss: 0.2238 ; Score: 0.916460338506267
# Val Loss: 0.6488 ; Score: 0.7846535273889046
# =====================
# =====================
# Epoch 50 completed
# Train Loss: 0.2211 ; Score: 0.9197510577400362
# Val Loss: 0.6414 ; Score: 0.7872507397701591
# =====================

# %%
df_train = pd.DataFrame({'loss': train_loss_collection,
                        'score': train_score_collection,
                        'type': "train"})

df_val = pd.DataFrame({'loss': val_loss_collection,
                        'score': val_score_collection,
                        'type': "val"})
df = pd.concat((df_train, df_val), axis=0).reset_index()
df['index'] = df['index'] + 1

# %%
from visualisation import LinePlot

X = ['index', 'index']
y = ['loss', 'score']
hue = ['type', 'type']
style_list = [None for _ in range(2)]
size_list = [None for _ in range(2)]

plotter = LinePlot(df)
fig, axes = plotter.multiple_plots(x_axis_list=X, y_axis_list=y, hue_list=hue,
                                      style_list=style_list, size_list=size_list, plots_each_row=2,
                                      kwarg={}, readable_label=False)

# %%
axes[0,0].set_title('Loss Graph')
axes[0,0].set_xlabel('Epoch')

axes[0,1].set_title('Val Graph')
axes[0,1].set_xlabel('Epoch')

fig

# %%
test_loss, test_score = performance.testing(metric_fn=metric_fn, kwargs={'average': 'macro'})
# Out:
# Test Loss: 0.6769076785184946 ; Score: 0.7842168554526893

# %%
import os
best_path = os.path.join('Trained Model', "best_stacked_lstm_model.pth") 

torch.save({
    "model_state": best_state,
    "model_class": model.__class__.__name__,
    "model_args": lstm_params,
    "optimizer_state": optimizer.state_dict(),
    "epochs": epochs
}, best_path)
