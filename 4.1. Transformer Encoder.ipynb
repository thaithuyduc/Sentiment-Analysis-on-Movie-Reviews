# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from collections import OrderedDict
from typing import Literal, Optional
from sklearn.metrics import f1_score
import copy
from matplotlib.ticker import FuncFormatter
from matplotlib.axes import Axes
from matplotlib.figure import Figure
import seaborn.objects as so
import math
import itertools
import matplotlib.ticker as mticker
import random

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %% [markdown]
# # Tiền xử lý dữ liệu

# %%
dfFilm_C = pd.read_csv("Dataset/film_cleaned_ver2.csv") #file sau khi gán thủ công
dfFilm_C.head()
# Out:
#                    author                                            comment  \
# 0       Nguyễn Thanh Trúc  Ta nói nó hài . Bản thân t con gái nhưng rất t...
# 1           Trần Công Lập  Hên là coi ở CGV, phim gì mà nhân vật nói chả ...
# 2  Nguyễn Bảo Thoại Trinh  phim hài, cười banh rạp =)))) Nửa tiếng đầu mì...
# 3         Dương Thanh Huy  Nếu bỏ tiền mua vé xem Phim Việt thì tui tốn c...
# 4     Trần Thị Thanh Sang  Phim hay và ý nghĩa. Cười rất nhiều. Có nhìu h...
#
#   ratings                     title  \
# 0    5/10  Truy Tìm Long Diên Hương
# 1    2/10  Truy Tìm Long Diên Hương
# 2    7/10  Truy Tìm Long Diên Hương
# 3    5/10  Truy Tìm Long Diên Hương
# 4    5/10  Truy Tìm Long Diên Hương
#
#                                                  url  \
# 0  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 1  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 2  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 3  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 4  https://www.momo.vn/cinema/truy-tim-long-dien-...
#
#                                         cleaned_text  length  has_emoji  \
# 0  ta nói nó hài bản thân tôi con gái nhưng rất t...      23          0
# 1  hên coi ở cgv phim gì nhân vật nói chả nghe cá...      51          0
# 2  phim hài cười banh rạp = nửa tiếng đầu mình bi...      36          0
# 3  nếu bỏ tiền mua vé xem phim việt tui tốn chưa ...     231          0
# 4  phim hay ý nghĩa cười rất nhiều có nhìu hành đ...      14          0
#
#       label
# 0  positive
# 1  negative
# 2  positive
# 3  positive
# 4  positive

# %%
# Lấy ra những cột thật sự cần cho SA
df_needed = dfFilm_C[['cleaned_text', 'label']]
df_needed.head()
# Out:
#                                         cleaned_text     label
# 0  ta nói nó hài bản thân tôi con gái nhưng rất t...  positive
# 1  hên coi ở cgv phim gì nhân vật nói chả nghe cá...  negative
# 2  phim hài cười banh rạp = nửa tiếng đầu mình bi...  positive
# 3  nếu bỏ tiền mua vé xem phim việt tui tốn chưa ...  positive
# 4  phim hay ý nghĩa cười rất nhiều có nhìu hành đ...  positive

# %%
df_needed['label'].value_counts()
# Out:
# label
# positive         2005
# negative         1841
# mixed/neutral    1233
# none              328
# Name: count, dtype: int64

# %%
# Loại bỏ đi Label là none có trong dữ liệu
df_needed = df_needed[df_needed['label'].isin(['positive', 'negative', 'mixed/neutral'])]

# %% [markdown]
# # Chuẩn bị dữ liệu cho mô hình học sâu

# %%
# Xây dựng Vocabulary cho tập dữ liệu trên
def build_vocab(corpus: pd.Series) -> dict[str, int]:
    """
    Build vocabulary
    """
    # vectorize short_description to get the vocabulary
    vocab_vectorizer = CountVectorizer(min_df=1, max_df=1.0, stop_words=None)
    matrix = vocab_vectorizer.fit_transform(corpus)
    vocab = vocab_vectorizer.vocabulary_
    
    df = pd.DataFrame(list(vocab.items()), columns=['word', 'index'])
    df['index'] = df['index'] + 2

    df_pad = pd.DataFrame(list({"<PAD>": 0, "<UNK>": 1}.items()), columns=["word", "index"])
    df = pd.concat([df, df_pad], axis=0, ignore_index=True)
    
    vocab = dict(zip(df['word'], df['index']))
    
    return vocab

# %%
# Tạo dictionary để map label thành số
label = df_needed['label'].unique()
idx = range(len(label))
label_mapping = dict(zip(label, idx))
label_mapping
# Out:
# {'positive': 0, 'negative': 1, 'mixed/neutral': 2}

# %%
# Chia tập dữ liệu thành train, val, test dataset
X = df_needed['cleaned_text']
y = df_needed['label']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.2, stratify=y_train, random_state=42)

# %%
vocab=build_vocab(X_train)
len(vocab)
# Out:
# 4913

# %%
from torch.nn.utils.rnn import pad_sequence
class SentimentDataset(Dataset):
    def __init__(self, vocab, text: pd.Series, label: pd.Series, label_mapping):
        super().__init__()
        self.vocab = vocab
        self.text = text
        self.label = label
        self.label_mapping = label_mapping

    def __len__(self):
        return len(self.text)

    def __getitem__(self, idx) -> tuple[torch.LongTensor, torch.LongTensor]:  # iterate through each sample, must have "idx"
        # get text at index
        text_item = self.text.iloc[idx]
        label_item = self.label.iloc[idx]

        # tokenize
        tokens = text_item.split()
        tokens_idx = [self.vocab[token] if token in self.vocab else self.vocab['<UNK>'] for token in tokens] # list
        label_idx = self.label_mapping[label_item]

        return torch.tensor(tokens_idx, dtype=torch.long), torch.tensor(label_idx, dtype=torch.long)

def collate_fn(batch) -> tuple[torch.LongTensor, torch.LongTensor]:
    tokens_idx, label = zip(*batch) # return tuples
    labels = torch.stack(label, dim=0)
    
    # Pad the sequences
    padded_sequences = pad_sequence(tokens_idx, batch_first=True,
                                    padding_value=vocab["<PAD>"])
    
    return padded_sequences, labels

# %%
train_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_train, label=y_train)

val_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_val, label=y_val)

test_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_test, label=y_test)

# %%
train_loader = DataLoader(train_dataset, batch_size = 256, shuffle=True, collate_fn = collate_fn)

val_loader = DataLoader(val_dataset, batch_size = 256, shuffle=False, collate_fn = collate_fn)

test_loader = DataLoader(test_dataset, batch_size = 256, shuffle=False, collate_fn = collate_fn)

# used to create mini-batch

# %% [markdown]
# # Huấn luyện mô hình

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
epochs = 40

loss_function = nn.CrossEntropyLoss()
metric_fn = f1_score

transformer_params = {
    'vocab': vocab,
    'emb_dim': 256,
    'num_heads': 8,
    'ffn_dim': 512,
    'num_transformer_layers': 1,
    'pooling_fn': 'mean',
    'num_classes': y_train.nunique()
}

# %%
from helper_class import ModelTraining
from Model.transformer import EncoderTransformerModel

model = EncoderTransformerModel(**transformer_params)
model = torch.nn.DataParallel(model)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr= 0.008, weight_decay=1e-3)  # weight_decay=1e-2

performance = ModelTraining(model=model, optimizer=optimizer, loss_function=loss_function,
                             device=device, train_loader=train_loader, val_loader=val_loader,
                             test_loader=test_loader)

# %%
train_loss_collection, val_loss_collection, train_score_collection, val_score_collection, best_state = \
performance.training_session(epochs=epochs, metric_fn=metric_fn, kwargs={'average': 'macro'})
# Out:
# New best score in epoch 1: 0.188661491413785. Saving model parameters...
# =====================
# Epoch 1 completed
# Train Loss: 1.1964 ; Score: 0.3258298666361284
# Val Loss: 1.0790 ; Score: 0.188661491413785
# =====================
# =====================
# Epoch 2 completed
# Train Loss: 1.0946 ; Score: 0.2842821937506907
# Val Loss: 1.0844 ; Score: 0.17726396917148365
# =====================
# New best score in epoch 3: 0.39148182153112004. Saving model parameters...
# =====================
# Epoch 3 completed
# Train Loss: 1.0723 ; Score: 0.3061870578492149
# Val Loss: 1.0038 ; Score: 0.39148182153112004
# =====================
# New best score in epoch 4: 0.4097306851835468. Saving model parameters...
# =====================
# Epoch 4 completed
# Train Loss: 1.0213 ; Score: 0.3583370990966496
# Val Loss: 0.9399 ; Score: 0.4097306851835468
# =====================
# New best score in epoch 5: 0.45068045977011506. Saving model parameters...
# =====================
# Epoch 5 completed
# Train Loss: 0.9553 ; Score: 0.42355987778522985
# Val Loss: 0.8946 ; Score: 0.45068045977011506
# =====================
# New best score in epoch 6: 0.4625273249720189. Saving model parameters...
# =====================
# Epoch 6 completed
# Train Loss: 0.8676 ; Score: 0.47796283124383804
# Val Loss: 0.8789 ; Score: 0.4625273249720189
# =====================
# New best score in epoch 7: 0.5810663489579075. Saving model parameters...
# =====================
# Epoch 7 completed
# Train Loss: 0.7997 ; Score: 0.5324873091937664
# Val Loss: 0.7857 ; Score: 0.5810663489579075
# =====================
# New best score in epoch 8: 0.6442945233769889. Saving model parameters...
# =====================
# Epoch 8 completed
# Train Loss: 0.7432 ; Score: 0.6178050875681097
# Val Loss: 0.7485 ; Score: 0.6442945233769889
# =====================
# =====================
# Epoch 9 completed
# Train Loss: 0.7156 ; Score: 0.6397222663943938
# Val Loss: 1.2375 ; Score: 0.48459095165206084
# =====================
# =====================
# Epoch 10 completed
# Train Loss: 0.8313 ; Score: 0.5832796321589523
# Val Loss: 0.7566 ; Score: 0.6129522523345353
# =====================
# =====================
# Epoch 11 completed
# Train Loss: 0.7304 ; Score: 0.6220471412454142
# Val Loss: 0.7400 ; Score: 0.6431066142232643
# =====================
# New best score in epoch 12: 0.6933219800488213. Saving model parameters...
# =====================
# Epoch 12 completed
# Train Loss: 0.6612 ; Score: 0.695798414349149
# Val Loss: 0.6906 ; Score: 0.6933219800488213
# =====================
# =====================
# Epoch 13 completed
# Train Loss: 0.6656 ; Score: 0.680553324398424
# Val Loss: 0.7431 ; Score: 0.6580678628073623
# =====================
# New best score in epoch 14: 0.695669584173765. Saving model parameters...
# =====================
# Epoch 14 completed
# Train Loss: 0.6402 ; Score: 0.7037440946091168
# Val Loss: 0.6862 ; Score: 0.695669584173765
# =====================
# =====================
# Epoch 15 completed
# Train Loss: 0.6512 ; Score: 0.7100802099653184
# Val Loss: 0.7629 ; Score: 0.5962492831035339
# =====================
# New best score in epoch 16: 0.7032496002127459. Saving model parameters...
# =====================
# Epoch 16 completed
# Train Loss: 0.6217 ; Score: 0.6964405475707928
# Val Loss: 0.6613 ; Score: 0.7032496002127459
# =====================
# =====================
# Epoch 17 completed
# Train Loss: 0.5426 ; Score: 0.7603665818393025
# Val Loss: 0.6859 ; Score: 0.6886977900431478
# =====================
# =====================
# Epoch 18 completed
# Train Loss: 0.5363 ; Score: 0.7735917647046481
# Val Loss: 0.7145 ; Score: 0.6653491825397682
# =====================
# New best score in epoch 19: 0.7144565982701038. Saving model parameters...
# =====================
# Epoch 19 completed
# Train Loss: 0.5340 ; Score: 0.7660998731657346
# Val Loss: 0.6458 ; Score: 0.7144565982701038
# =====================
# =====================
# Epoch 20 completed
# Train Loss: 0.5156 ; Score: 0.7809216472547793
# Val Loss: 0.7227 ; Score: 0.7076692404817405
# =====================
# =====================
# Epoch 21 completed
# Train Loss: 0.5258 ; Score: 0.7808623646869103
# Val Loss: 0.6910 ; Score: 0.7040827064014828
# =====================
# New best score in epoch 22: 0.71775827362497. Saving model parameters...
# =====================
# Epoch 22 completed
# Train Loss: 0.5117 ; Score: 0.776809740931964
# Val Loss: 0.6181 ; Score: 0.71775827362497
# =====================
# =====================
# Epoch 23 completed
# Train Loss: 0.4437 ; Score: 0.8073205927764538
# Val Loss: 0.6260 ; Score: 0.7159099863264502
# =====================
# =====================
# Epoch 24 completed
# Train Loss: 0.4582 ; Score: 0.8093538564060326
# Val Loss: 0.6302 ; Score: 0.7167432614337059
# =====================
# =====================
# Epoch 25 completed
# Train Loss: 0.4944 ; Score: 0.7965517475583536
# Val Loss: 0.7215 ; Score: 0.7015791329121793
# =====================
# =====================
# Epoch 26 completed
# Train Loss: 0.4621 ; Score: 0.8098672941555174
# Val Loss: 0.7027 ; Score: 0.6942396903038534
# =====================
# =====================
# Epoch 27 completed
# Train Loss: 0.4480 ; Score: 0.8189888081929605
# Val Loss: 0.6799 ; Score: 0.6744943734737182
# =====================
# =====================
# Epoch 28 completed
# Train Loss: 0.4240 ; Score: 0.8195020064220309
# Val Loss: 0.7015 ; Score: 0.7089175927056409
# =====================
# =====================
# Epoch 29 completed
# Train Loss: 0.4242 ; Score: 0.8212338822863345
# Val Loss: 0.7229 ; Score: 0.6933744131601921
# =====================
# =====================
# Epoch 30 completed
# Train Loss: 0.4382 ; Score: 0.8148178028002544
# Val Loss: 0.6491 ; Score: 0.7152938787275241
# =====================
# =====================
# Epoch 31 completed
# Train Loss: 0.4933 ; Score: 0.7823627869646912
# Val Loss: 0.6096 ; Score: 0.7018589309637133
# =====================
# =====================
# Epoch 32 completed
# Train Loss: 0.4167 ; Score: 0.828898679327362
# Val Loss: 0.6797 ; Score: 0.7049853913225653
# =====================
# New best score in epoch 33: 0.7202145820683136. Saving model parameters...
# =====================
# Epoch 33 completed
# Train Loss: 0.3780 ; Score: 0.8397543060550424
# Val Loss: 0.6999 ; Score: 0.7202145820683136
# =====================
# New best score in epoch 34: 0.7228597375656199. Saving model parameters...
# =====================
# Epoch 34 completed
# Train Loss: 0.3987 ; Score: 0.8330360533216427
# Val Loss: 0.6818 ; Score: 0.7228597375656199
# =====================
# =====================
# Epoch 35 completed
# Train Loss: 0.3702 ; Score: 0.8447462077240203
# Val Loss: 0.6908 ; Score: 0.7192034913096562
# =====================
# =====================
# Epoch 36 completed
# Train Loss: 0.3649 ; Score: 0.850060495740142
# Val Loss: 0.7326 ; Score: 0.7202755800465104
# =====================
# =====================
# Epoch 37 completed
# Train Loss: 0.2973 ; Score: 0.8828944361603656
# Val Loss: 0.7968 ; Score: 0.6848602044509094
# =====================
# =====================
# Epoch 38 completed
# Train Loss: 0.3587 ; Score: 0.8551923791865038
# Val Loss: 0.7445 ; Score: 0.6963855056891037
# =====================
# =====================
# Epoch 39 completed
# Train Loss: 0.3537 ; Score: 0.852370459275201
# Val Loss: 0.7231 ; Score: 0.7037409206629809
# =====================
# New best score in epoch 40: 0.7321562869452238. Saving model parameters...
# =====================
# Epoch 40 completed
# Train Loss: 0.3237 ; Score: 0.8669087295353703
# Val Loss: 0.6717 ; Score: 0.7321562869452238
# =====================

# %%
df_train = pd.DataFrame({'loss': train_loss_collection,
                        'score': train_score_collection,
                        'type': "train"})

df_val = pd.DataFrame({'loss': val_loss_collection,
                        'score': val_score_collection,
                        'type': "val"})
df = pd.concat((df_train, df_val), axis=0).reset_index()
df['index'] = df['index'] + 1

# %%
from visualisation import LinePlot

X = ['index', 'index']
y = ['loss', 'score']
hue = ['type', 'type']
style_list = [None for _ in range(2)]
size_list = [None for _ in range(2)]

plotter = LinePlot(df)
fig, axes = plotter.multiple_plots(x_axis_list=X, y_axis_list=y, hue_list=hue,
                                      style_list=style_list, size_list=size_list, plots_each_row=2,
                                      kwarg={}, readable_label=False)

# %%
axes[0,0].set_title('Loss Graph')
axes[0,0].set_xlabel('Epoch')

axes[0,1].set_title('Metric Graph')
axes[0,1].set_xlabel('Epoch')

fig

# %%
test_loss, test_score = performance.testing(metric_fn=metric_fn, kwargs={'average': 'macro'})
# Out:
# Test Loss: 0.6585379781758214 ; Score: 0.7325577125326813

# %%
import os
best_path = os.path.join('Trained Model', "best_transformer_model.pth") 

torch.save({
    "model_state": best_state,
    "model_class": model.__class__.__name__,
    "model_args": transformer_params,
    "optimizer_state": optimizer.state_dict(),
    "epochs": epochs
}, best_path)
