# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from collections import OrderedDict
from typing import Literal, Optional
from sklearn.metrics import f1_score
import copy
from matplotlib.ticker import FuncFormatter
from matplotlib.axes import Axes
from matplotlib.figure import Figure
import seaborn.objects as so
import math
import itertools
import matplotlib.ticker as mticker
import random

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %%
dfFilm_C = pd.read_csv("Dataset/film_cleaned_ver2.csv") #file sau khi gán thủ công
dfFilm_C.head()
# Out:
#                    author                                            comment  \
# 0       Nguyễn Thanh Trúc  Ta nói nó hài . Bản thân t con gái nhưng rất t...
# 1           Trần Công Lập  Hên là coi ở CGV, phim gì mà nhân vật nói chả ...
# 2  Nguyễn Bảo Thoại Trinh  phim hài, cười banh rạp =)))) Nửa tiếng đầu mì...
# 3         Dương Thanh Huy  Nếu bỏ tiền mua vé xem Phim Việt thì tui tốn c...
# 4     Trần Thị Thanh Sang  Phim hay và ý nghĩa. Cười rất nhiều. Có nhìu h...
#
#   ratings                     title  \
# 0    5/10  Truy Tìm Long Diên Hương
# 1    2/10  Truy Tìm Long Diên Hương
# 2    7/10  Truy Tìm Long Diên Hương
# 3    5/10  Truy Tìm Long Diên Hương
# 4    5/10  Truy Tìm Long Diên Hương
#
#                                                  url  \
# 0  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 1  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 2  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 3  https://www.momo.vn/cinema/truy-tim-long-dien-...
# 4  https://www.momo.vn/cinema/truy-tim-long-dien-...
#
#                                         cleaned_text  length  has_emoji  \
# 0  ta nói nó hài bản thân tôi con gái nhưng rất t...      23          0
# 1  hên coi ở cgv phim gì nhân vật nói chả nghe cá...      51          0
# 2  phim hài cười banh rạp = nửa tiếng đầu mình bi...      36          0
# 3  nếu bỏ tiền mua vé xem phim việt tui tốn chưa ...     231          0
# 4  phim hay ý nghĩa cười rất nhiều có nhìu hành đ...      14          0
#
#       label
# 0  positive
# 1  negative
# 2  positive
# 3  positive
# 4  positive

# %%
# Lấy ra những cột thật sự cần cho SA
df_needed = dfFilm_C[['cleaned_text', 'label']]
df_needed.head()
# Out:
#                                         cleaned_text     label
# 0  ta nói nó hài bản thân tôi con gái nhưng rất t...  positive
# 1  hên coi ở cgv phim gì nhân vật nói chả nghe cá...  negative
# 2  phim hài cười banh rạp = nửa tiếng đầu mình bi...  positive
# 3  nếu bỏ tiền mua vé xem phim việt tui tốn chưa ...  positive
# 4  phim hay ý nghĩa cười rất nhiều có nhìu hành đ...  positive

# %%
df_needed['label'].value_counts()
# Out:
# label
# positive         2005
# negative         1841
# mixed/neutral    1233
# none              328
# Name: count, dtype: int64

# %%
# Loại bỏ đi Label là none có trong dữ liệu
df_needed = df_needed[df_needed['label'].isin(['positive', 'negative', 'mixed/neutral'])]

# %% [markdown]
# # Prepare Data

# %%
# Xây dựng Vocabulary cho tập dữ liệu trên
def build_vocab(corpus: pd.Series) -> dict[str, int]:
    """
    Build vocabulary
    """
    # vectorize short_description to get the vocabulary
    vocab_vectorizer = CountVectorizer(min_df=1, max_df=1.0, stop_words=None)
    matrix = vocab_vectorizer.fit_transform(corpus)
    vocab = vocab_vectorizer.vocabulary_
    
    df = pd.DataFrame(list(vocab.items()), columns=['word', 'index'])
    df['index'] = df['index'] + 2

    df_pad = pd.DataFrame(list({"<PAD>": 0, "<UNK>": 1}.items()), columns=["word", "index"])
    df = pd.concat([df, df_pad], axis=0, ignore_index=True)
    
    vocab = dict(zip(df['word'], df['index']))
    
    return vocab

# %%
# Tạo dictionary để map label thành số
label = df_needed['label'].unique()
idx = range(len(label))
label_mapping = dict(zip(label, idx))
label_mapping
# Out:
# {'positive': 0, 'negative': 1, 'mixed/neutral': 2}

# %%
# Chia tập dữ liệu thành train, val, test dataset
X = df_needed['cleaned_text']
y = df_needed['label']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.2, stratify=y_train, random_state=42)

# %%
vocab=build_vocab(X_train)
len(vocab)
# Out:
# 4913

# %%
from torch.nn.utils.rnn import pad_sequence
class SentimentDataset(Dataset):
    def __init__(self, vocab:dict[str, int], text: pd.Series, label: pd.Series, label_mapping:dict[str, int]):
        super().__init__()
        self.vocab = vocab
        self.text = text
        self.label = label
        self.label_mapping = label_mapping

    def __len__(self):
        return len(self.text)

    def __getitem__(self, idx) -> tuple[torch.LongTensor, torch.LongTensor]:  # iterate through each sample, must have "idx"
        # get text at index
        text_item = self.text.iloc[idx]
        label_item = self.label.iloc[idx]

        # tokenize
        tokens = text_item.split()
        tokens_idx = [self.vocab[token] if token in self.vocab else self.vocab['<UNK>'] for token in tokens] # list
        label_idx = self.label_mapping[label_item]

        return torch.tensor(tokens_idx, dtype=torch.long), torch.tensor(label_idx, dtype=torch.long)

def collate_fn(batch) -> tuple[torch.LongTensor, torch.LongTensor]:
    tokens_idx, label = zip(*batch) # return tuples
    labels = torch.stack(label, dim=0)
    
    # Pad the sequences
    padded_sequences = pad_sequence(tokens_idx, batch_first=True,
                                    padding_value=vocab["<PAD>"])
    
    return padded_sequences, labels

# %%
train_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_train, label=y_train)

val_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_val, label=y_val)

test_dataset = SentimentDataset(vocab=vocab, label_mapping=label_mapping,
                                    text=X_test, label=y_test)

# %%
train_loader = DataLoader(train_dataset, batch_size = 512, shuffle=True, collate_fn = collate_fn)

val_loader = DataLoader(val_dataset, batch_size = 512, shuffle=False, collate_fn = collate_fn)

test_loader = DataLoader(test_dataset, batch_size = 512, shuffle=False, collate_fn = collate_fn)

# used to create mini-batch

# %% [markdown]
# # Train GRU Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
epochs = 50

loss_function = nn.CrossEntropyLoss()
metric_fn = f1_score

gru_params = {'vocab': vocab,
              'emb_dim': 128, 
              'num_classes': y_train.nunique(),
              'hidden_size': 128,
              'num_layers': 1,
              'bidirectional': False,
              'pooling_fn': 'attention'
             }

# %%
from helper_class import ModelTraining
from Model.gru import GRUModel

model = GRUModel(**gru_params)
model = torch.nn.DataParallel(model)
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr= 0.001, weight_decay=1e-3) # weight_decay=1e-3

performance = ModelTraining(model=model, optimizer=optimizer, loss_function=loss_function,
                             device=device, train_loader=train_loader, val_loader=val_loader,
                             test_loader=test_loader)

# %%
train_loss_collection, val_loss_collection, train_score_collection, val_score_collection, best_state = \
performance.training_session(epochs=epochs, metric_fn=metric_fn, kwargs={'average': 'macro'})
# Out:
# New best score in epoch 1: 0.44325209074984456. Saving model parameters...
# =====================
# Epoch 1 completed
# Train Loss: 1.0933 ; Score: 0.36334466906479773
# Val Loss: 0.9203 ; Score: 0.44325209074984456
# =====================
# New best score in epoch 2: 0.6187448276260105. Saving model parameters...
# =====================
# Epoch 2 completed
# Train Loss: 0.9536 ; Score: 0.4887498483901522
# Val Loss: 0.7830 ; Score: 0.6187448276260105
# =====================
# New best score in epoch 3: 0.6435515822982857. Saving model parameters...
# =====================
# Epoch 3 completed
# Train Loss: 0.8400 ; Score: 0.5870294930742918
# Val Loss: 0.7684 ; Score: 0.6435515822982857
# =====================
# New best score in epoch 4: 0.664483686767836. Saving model parameters...
# =====================
# Epoch 4 completed
# Train Loss: 0.8038 ; Score: 0.6307745641739688
# Val Loss: 0.7481 ; Score: 0.664483686767836
# =====================
# New best score in epoch 5: 0.6800749512065973. Saving model parameters...
# =====================
# Epoch 5 completed
# Train Loss: 0.7479 ; Score: 0.6668754547952679
# Val Loss: 0.7204 ; Score: 0.6800749512065973
# =====================
# New best score in epoch 6: 0.7079460348114148. Saving model parameters...
# =====================
# Epoch 6 completed
# Train Loss: 0.7149 ; Score: 0.685353472109457
# Val Loss: 0.6672 ; Score: 0.7079460348114148
# =====================
# New best score in epoch 7: 0.7192207198516108. Saving model parameters...
# =====================
# Epoch 7 completed
# Train Loss: 0.6695 ; Score: 0.7156643466030728
# Val Loss: 0.6438 ; Score: 0.7192207198516108
# =====================
# New best score in epoch 8: 0.7255105613257089. Saving model parameters...
# =====================
# Epoch 8 completed
# Train Loss: 0.6533 ; Score: 0.7131996106259768
# Val Loss: 0.6334 ; Score: 0.7255105613257089
# =====================
# =====================
# Epoch 9 completed
# Train Loss: 0.6360 ; Score: 0.7318102089654676
# Val Loss: 0.6415 ; Score: 0.7250328912506107
# =====================
# New best score in epoch 10: 0.7336168091164114. Saving model parameters...
# =====================
# Epoch 10 completed
# Train Loss: 0.6098 ; Score: 0.7376494352897086
# Val Loss: 0.6280 ; Score: 0.7336168091164114
# =====================
# New best score in epoch 11: 0.7345578141197894. Saving model parameters...
# =====================
# Epoch 11 completed
# Train Loss: 0.5788 ; Score: 0.7538306490814451
# Val Loss: 0.6155 ; Score: 0.7345578141197894
# =====================
# New best score in epoch 12: 0.7425963927923406. Saving model parameters...
# =====================
# Epoch 12 completed
# Train Loss: 0.5351 ; Score: 0.7751310146417918
# Val Loss: 0.6008 ; Score: 0.7425963927923406
# =====================
# New best score in epoch 13: 0.7627076668658198. Saving model parameters...
# =====================
# Epoch 13 completed
# Train Loss: 0.5202 ; Score: 0.78079133938551
# Val Loss: 0.5857 ; Score: 0.7627076668658198
# =====================
# =====================
# Epoch 14 completed
# Train Loss: 0.5131 ; Score: 0.7963986676435878
# Val Loss: 0.6432 ; Score: 0.7367851398294202
# =====================
# =====================
# Epoch 15 completed
# Train Loss: 0.5454 ; Score: 0.7733404117837598
# Val Loss: 0.6008 ; Score: 0.760540876917818
# =====================
# =====================
# Epoch 16 completed
# Train Loss: 0.5071 ; Score: 0.7924214889494037
# Val Loss: 0.6092 ; Score: 0.7447202571374638
# =====================
# =====================
# Epoch 17 completed
# Train Loss: 0.5008 ; Score: 0.7908720420922833
# Val Loss: 0.5937 ; Score: 0.7488787874913544
# =====================
# New best score in epoch 18: 0.7781836579289853. Saving model parameters...
# =====================
# Epoch 18 completed
# Train Loss: 0.4597 ; Score: 0.8061676908093215
# Val Loss: 0.5585 ; Score: 0.7781836579289853
# =====================
# =====================
# Epoch 19 completed
# Train Loss: 0.4585 ; Score: 0.8129024209940661
# Val Loss: 0.5479 ; Score: 0.7737030286319876
# =====================
# =====================
# Epoch 20 completed
# Train Loss: 0.4291 ; Score: 0.8245869727503691
# Val Loss: 0.5690 ; Score: 0.7697508484280285
# =====================
# =====================
# Epoch 21 completed
# Train Loss: 0.4251 ; Score: 0.8284548632933508
# Val Loss: 0.5925 ; Score: 0.7724050554052261
# =====================
# New best score in epoch 22: 0.7811209393625237. Saving model parameters...
# =====================
# Epoch 22 completed
# Train Loss: 0.4181 ; Score: 0.830179522755771
# Val Loss: 0.5726 ; Score: 0.7811209393625237
# =====================
# New best score in epoch 23: 0.7862701297817635. Saving model parameters...
# =====================
# Epoch 23 completed
# Train Loss: 0.3939 ; Score: 0.8466171450411603
# Val Loss: 0.5609 ; Score: 0.7862701297817635
# =====================
# =====================
# Epoch 24 completed
# Train Loss: 0.3980 ; Score: 0.8391811478974419
# Val Loss: 0.5573 ; Score: 0.779135527857515
# =====================
# =====================
# Epoch 25 completed
# Train Loss: 0.3916 ; Score: 0.8406660735664632
# Val Loss: 0.5719 ; Score: 0.7777165613805547
# =====================
# =====================
# Epoch 26 completed
# Train Loss: 0.3992 ; Score: 0.8377355093441485
# Val Loss: 0.5490 ; Score: 0.7840964993989529
# =====================
# =====================
# Epoch 27 completed
# Train Loss: 0.3770 ; Score: 0.8473506395825124
# Val Loss: 0.5634 ; Score: 0.784969485122963
# =====================
# =====================
# Epoch 28 completed
# Train Loss: 0.3773 ; Score: 0.8511659218494972
# Val Loss: 0.5667 ; Score: 0.7834954156773241
# =====================
# New best score in epoch 29: 0.7970000506075222. Saving model parameters...
# =====================
# Epoch 29 completed
# Train Loss: 0.3631 ; Score: 0.8569184389956931
# Val Loss: 0.5620 ; Score: 0.7970000506075222
# =====================
# =====================
# Epoch 30 completed
# Train Loss: 0.3652 ; Score: 0.8512366750347359
# Val Loss: 0.5816 ; Score: 0.7756453652852637
# =====================
# =====================
# Epoch 31 completed
# Train Loss: 0.3814 ; Score: 0.8465232655947529
# Val Loss: 0.5546 ; Score: 0.7895977431895673
# =====================
# =====================
# Epoch 32 completed
# Train Loss: 0.3444 ; Score: 0.8623803955791973
# Val Loss: 0.6076 ; Score: 0.7696239115614164
# =====================
# =====================
# Epoch 33 completed
# Train Loss: 0.3656 ; Score: 0.8618777408074654
# Val Loss: 0.5896 ; Score: 0.777739488541887
# =====================
# =====================
# Epoch 34 completed
# Train Loss: 0.3391 ; Score: 0.8649475493984099
# Val Loss: 0.5561 ; Score: 0.7862288961182577
# =====================
# =====================
# Epoch 35 completed
# Train Loss: 0.3089 ; Score: 0.8801359101315404
# Val Loss: 0.5746 ; Score: 0.7833900219161826
# =====================
# =====================
# Epoch 36 completed
# Train Loss: 0.3158 ; Score: 0.8761099578062809
# Val Loss: 0.5937 ; Score: 0.7729589636940938
# =====================
# =====================
# Epoch 37 completed
# Train Loss: 0.3117 ; Score: 0.8765362597356043
# Val Loss: 0.6233 ; Score: 0.7746138580265516
# =====================
# =====================
# Epoch 38 completed
# Train Loss: 0.3155 ; Score: 0.8718698779533721
# Val Loss: 0.6147 ; Score: 0.7835161216339378
# =====================
# =====================
# Epoch 39 completed
# Train Loss: 0.3252 ; Score: 0.8646796712545273
# Val Loss: 0.5866 ; Score: 0.7823752451749032
# =====================
# =====================
# Epoch 40 completed
# Train Loss: 0.3042 ; Score: 0.8819329841827837
# Val Loss: 0.5998 ; Score: 0.7836699843457936
# =====================
# =====================
# Epoch 41 completed
# Train Loss: 0.3079 ; Score: 0.8768190963328905
# Val Loss: 0.5898 ; Score: 0.790251476994409
# =====================
# =====================
# Epoch 42 completed
# Train Loss: 0.2946 ; Score: 0.885117600705582
# Val Loss: 0.5948 ; Score: 0.7835610611468543
# =====================
# =====================
# Epoch 43 completed
# Train Loss: 0.2937 ; Score: 0.8840141569580265
# Val Loss: 0.6435 ; Score: 0.7651775116667231
# =====================
# =====================
# Epoch 44 completed
# Train Loss: 0.2958 ; Score: 0.8785364165667259
# Val Loss: 0.5699 ; Score: 0.7942122937359972
# =====================
# =====================
# Epoch 45 completed
# Train Loss: 0.2657 ; Score: 0.8940975026112082
# Val Loss: 0.5975 ; Score: 0.7845654499866095
# =====================
# =====================
# Epoch 46 completed
# Train Loss: 0.2582 ; Score: 0.8988664940495834
# Val Loss: 0.6414 ; Score: 0.7791963812144633
# =====================
# =====================
# Epoch 47 completed
# Train Loss: 0.2697 ; Score: 0.8999069742983347
# Val Loss: 0.6115 ; Score: 0.7814513764645804
# =====================
# =====================
# Epoch 48 completed
# Train Loss: 0.2799 ; Score: 0.8874942326324217
# Val Loss: 0.6444 ; Score: 0.7771123338197126
# =====================
# =====================
# Epoch 49 completed
# Train Loss: 0.2802 ; Score: 0.8983302503881986
# Val Loss: 0.6013 ; Score: 0.7810910731598267
# =====================
# =====================
# Epoch 50 completed
# Train Loss: 0.2587 ; Score: 0.9007258583919452
# Val Loss: 0.6270 ; Score: 0.7828801750941037
# =====================

# %%
df_train = pd.DataFrame({'loss': train_loss_collection,
                        'score': train_score_collection,
                        'type': "train"})

df_val = pd.DataFrame({'loss': val_loss_collection,
                        'score': val_score_collection,
                        'type': "val"})
df = pd.concat((df_train, df_val), axis=0).reset_index()
df['index'] = df['index'] + 1

# %%
from visualisation import LinePlot

X = ['index', 'index']
y = ['loss', 'score']
hue = ['type', 'type']
style_list = [None for _ in range(2)]
size_list = [None for _ in range(2)]

plotter = LinePlot(df)
fig, axes = plotter.multiple_plots(x_axis_list=X, y_axis_list=y, hue_list=hue,
                                      style_list=style_list, size_list=size_list, plots_each_row=2,
                                      kwarg={}, readable_label=False)

# %%
axes[0,0].set_title('Loss Graph')
axes[0,0].set_xlabel('Epoch')

axes[0,1].set_title('Val Graph')
axes[0,1].set_xlabel('Epoch')

fig

# %%
test_loss, test_score = performance.testing(metric_fn=metric_fn, kwargs={'average': 'macro'})
# Out:
# Test Loss: 0.591682772501515 ; Score: 0.7719689775245331

# %%
import os
best_path = os.path.join('Trained Model', "best_stacked_gru_model.pth") 

torch.save({
    "model_state": best_state,
    "model_class": model.__class__.__name__,
    "model_args": gru_params,
    "optimizer_state": optimizer.state_dict(),
    "epochs": epochs
}, best_path)
